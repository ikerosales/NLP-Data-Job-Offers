# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("andrewmvd/data-scientist-jobs")

print("Path to dataset files:", path)

import kagglehub

# Download latest version
path2 = kagglehub.dataset_download("andrewmvd/data-analyst-jobs")

print("Path to dataset files:", path2)

import kagglehub

# Download latest version
path3 = kagglehub.dataset_download("andrewmvd/business-analyst-jobs")

print("Path to dataset files:", path3)

import kagglehub

# Download latest version
path4 = kagglehub.dataset_download("andrewmvd/data-engineer-jobs")

print("Path to dataset files:", path4)
# Out:
# Path to dataset files: /kaggle/input/data-scientist-jobs
# Path to dataset files: /kaggle/input/data-analyst-jobs
# Path to dataset files: /kaggle/input/business-analyst-jobs
# Path to dataset files: /kaggle/input/data-engineer-jobs

# %%
import pandas as pd
df_datascience = pd.read_csv("/kaggle/input/data-scientist-jobs/DataScientist.csv")
df_dataanalyst = pd.read_csv("/kaggle/input/data-analyst-jobs/DataAnalyst.csv")
df_businessanalyst = pd.read_csv("/kaggle/input/business-analyst-jobs/BusinessAnalyst.csv")
df_dataengineer = pd.read_csv("/kaggle/input/data-engineer-jobs/DataEngineer.csv")

# %% [markdown]
# printeo para que se vea el error

# %%
df_businessanalyst
# Out:
#                                              Unnamed: 0  \
# 0                                                     0
# 1                                                     1
# 2                                                     2
# 3                                                     3
# 4                                                     4
# ...                                                 ...
# 4087                                  Help Desk Analyst
# 4088              System Analyst (Data) - PL/SQl Server
# 4089  Programmer Analyst- PeopleSoft ( Finance and S...
# 4090                            Loss Mitigation Analyst
# 4091                     Financial Analyst II - Baptist
#
#                             index  \
# 0                               0
# 1                               1
# 2                               2
# 3                               3
# 4                               4
# ...                           ...
# 4087  $66K-$114K (Glassdoor est.)
# ...

# %%
print(df_datascience.shape)
print(df_dataanalyst.shape)
print(df_businessanalyst.shape)
print(df_dataengineer.shape)
# Out:
# (3909, 17)
# (2253, 16)
# (4092, 17)
# (2528, 15)

# %%
for i in dataframes:
    print(len(i[i['Rating'] == 'Jacksonville, FL']))
# Out:
# 0
# 0
# 392
# 0

# %%
displaced_rows = pd.to_numeric(df_businessanalyst['index'], errors='coerce').isna()
df_businessanalyst.loc[displaced_rows, df_businessanalyst.columns[2:]] = df_businessanalyst.loc[displaced_rows, df_businessanalyst.columns[0:-2]].values

# %%
df_businessanalyst
# Out:
#                                              Unnamed: 0  \
# 0                                                     0
# 1                                                     1
# 2                                                     2
# 3                                                     3
# 4                                                     4
# ...                                                 ...
# 4087                                  Help Desk Analyst
# 4088              System Analyst (Data) - PL/SQl Server
# 4089  Programmer Analyst- PeopleSoft ( Finance and S...
# 4090                            Loss Mitigation Analyst
# 4091                     Financial Analyst II - Baptist
#
#                             index  \
# 0                               0
# 1                               1
# 2                               2
# 3                               3
# 4                               4
# ...                           ...
# 4087  $66K-$114K (Glassdoor est.)
# ...

# %%
dataframes = [df_datascience, df_dataanalyst, df_businessanalyst, df_dataengineer]


for df in dataframes:
    if 'index' in df.columns:
        df.drop(columns = 'index', inplace = True)
    if 'Unnamed: 0' in df.columns:
        df.drop(columns = 'Unnamed: 0', inplace = True)
    print(df.shape)
# Out:
# (3909, 15)
# (2253, 15)
# (4092, 15)
# (2528, 15)

# %%
df_concatenado = pd.concat(dataframes, ignore_index=True)

# %%
df_concatenado.head()
# Out:
#                            Job Title               Salary Estimate  \
# 0              Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1  Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2               Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                       Data Analyst  $111K-$181K (Glassdoor est.)
# 4             Director, Data Science  $111K-$181K (Glassdoor est.)
#
#                                      Job Description Rating  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...    3.5
# 1  At Noom, we use scientifically proven methods ...    4.5
# 2  Decode_M\n\nhttps://www.decode-m.com/\n\nData ...   -1.0
# 3  Sapphire Digital seeks a dynamic and driven mi...    3.4
# 4  Director, Data Science - (200537)\nDescription...    3.4
#
#                       Company Name       Location      Headquarters  \
# 0                      Hopper\n3.5   New York, NY  Montreal, Canada
# ...

# %%
df_concatenado.to_csv('dataset_trabajos_ai.csv')
